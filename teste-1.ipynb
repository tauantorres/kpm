# %% [markdown]
# # `READ ME`:
#
# <ul>
#     <li>Primeira avaliação dos documentos para automatização da <code>KPM</code></li>
#     <li>[Primeiro site] maersk: <a href="https://www.maersk.com/" target="_blank">Link</a></li>
#     <li>[Segundo site] mycmacgm: <a href="https://www.cma-cgm.com/my-cma-cgm" target="_blank">Link</a></li>
#     <li>[Terceiro site] hapag-lloyd: <a href="https://www.hapag-lloyd.com/en/home.html" target="_blank">Link</a></li>
#     <li>[Quarto site] one-ocean network express: <a href="https://br.one-line.com/pt-br" target="_blank">Link</a></li>
#     <li>[Quinto site] hamburg: <a href="https://www.hamburgsud.com/" target="_blank">Link</a></li>
# </ul>
# <hr>

# %%
import pandas as pd

path = "material/planilha.xlsx"

df = pd.read_excel(io=path, skiprows=1, usecols=lambda column: column not in ["Date"])
df.head()
# Out:
#                Company        Ports   Origin Incoterm   Vietnam  Philippines  \
# 0  Cis Van den Broeck       Antwerp  Belgium      EXW  0.147037      0.15463
# 1            40 Reefer       Santos   Brazil      EXW  0.250000      0.30393
# 2            40 Reefer        Suape   Brazil      EXW  0.356370      0.35637
# 3   HYLIFE Neepawa, CA     Montreal   Canada      EXW  0.143074      0.18363
# 4          Ariztía, CL  San Antonio    Chile      EXW  0.208556      0.00000
#
#       Japan  Singapore  Colombia  Thailand  ...  Barbados   Bahamas  \
# 0  0.116667   0.081481  0.220000      0.23  ...  0.231067  0.281884
# 1  0.269711   0.253374  0.329171      0.25  ...  0.311782  0.411782
# 2  0.370407   0.317593  0.329563      0.00  ...  0.000000  0.000000
# 3  0.225926   0.128815  0.181481      0.22  ...  0.263000  0.296111
# 4  0.510000   0.055630  0.250000      0.31  ...  0.000000  0.000000
#
#    Dominican Republic  Cape Verde     Haiti   Grenada  Canary Islands  \
# ...
